# %% [markdown]
# <a href="https://colab.research.google.com/github/Alupng/StockAnalysis/blob/main/Stock_Closing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Choose a stock ticker symbol
ticker = 'AAPL'

# Download last 30 days of stock data
data = yf.download(ticker, period='30d')

# Ensure 'Close' column is numeric and has no missing values
if 'Close' in data.columns and not data['Close'].dropna().empty:
    close_prices = data['Close'].dropna()

    print(f"\nStock: {ticker}")
    print(f"Minimum Close Price: {close_prices.min():.2f}")
    print(f"Maximum Close Price: {close_prices.max():.2f}")
    print(f"Average Close Price: {close_prices.mean():.2f}")

    # Plot closing prices
    plt.figure(figsize=(10, 5))
    plt.plot(data.index, close_prices, label='Close Price', color='blue')
    plt.title(f'{ticker} Stock Closing Prices - Last 30 Days')
    plt.xlabel('Date')
    plt.ylabel('Price ($)')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
else:
    print("Error: No valid 'Close' price data found.")
# Out:
# /tmp/ipython-input-4-2321358878.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period='30d')
# [*********************100%***********************]  1 of 1 completed
# Stock: AAPL
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4-2321358878.py in <cell line: 0>()
#      13
#      14     print(f"\nStock: {ticker}")
# ---> 15     print(f"Minimum Close Price: {close_prices.min():.2f}")
#      16     print(f"Maximum Close Price: {close_prices.max():.2f}")
#      17     print(f"Average Close Price: {close_prices.mean():.2f}")
#
# TypeError: unsupported format string passed to Series.__format__

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Choose a stock ticker symbol
ticker = 'AAPL'

# Download last 30 days of stock data
data = yf.download(ticker, period='30d')

# Ensure 'Close' column is numeric and has no missing values
if 'Close' in data.columns and not data['Close'].dropna().empty:
    close_prices = data['Close'].dropna()

    print(f"\nStock: {ticker}")
    print(f"Minimum Close Price: {close_prices.min():.2f}")
    print(f"Maximum Close Price: {close_prices.max():.2f}")
    print(f"Average Close Price: {close_prices.mean():.2f}")

    # Plot closing prices
    plt.figure(figsize=(10, 5))
    plt.plot(data.index, close_prices, label='Close Price', color='blue')
    plt.title(f'{ticker} Stock Closing Prices - Last 30 Days')
    plt.xlabel('Date')
    plt.ylabel('Price ($)')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
else:
    print("Error: No valid 'Close' price data found.")
# Out:
# /tmp/ipython-input-5-2190552650.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period='30d')
# [*********************100%***********************]  1 of 1 completed
# Stock: AAPL
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-5-2190552650.py in <cell line: 0>()
#      13
#      14     print(f"\nStock: {ticker}")
# ---> 15     print(f"Minimum Close Price: {close_prices.min():.2f}")
#      16     print(f"Maximum Close Price: {close_prices.max():.2f}")
#      17     print(f"Average Close Price: {close_prices.mean():.2f}")
#
# TypeError: unsupported format string passed to Series.__format__

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Choose stock ticker
ticker = 'AAPL'

# Download 30 days of data
data = yf.download(ticker, period='30d')

# Handle multi-index or unexpected structure
if isinstance(data.columns, pd.MultiIndex):
    close_prices = data['Close'][ticker].dropna()
else:
    close_prices = data['Close'].dropna()

# Check again to avoid errors
if not close_prices.empty:
    print(f"\nStock: {ticker}")
    print(f"Minimum Close Price: {float(close_prices.min()):.2f}")
    print(f"Maximum Close Price: {float(close_prices.max()):.2f}")
    print(f"Average Close Price: {float(close_prices.mean()):.2f}")

    # Plot
    plt.figure(figsize=(10, 5))
    plt.plot(close_prices.index, close_prices, label='Close Price', color='blue')
    plt.title(f'{ticker} Stock Closing Prices - Last 30 Days')
    plt.xlabel('Date')
    plt.ylabel('Price ($)')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()
else:
    print("No closing price data available.")
# Out:
# /tmp/ipython-input-6-909404877.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period='30d')
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-6-909404877.py in <cell line: 0>()
#       9
#      10 # Handle multi-index or unexpected structure
# ---> 11 if isinstance(data.columns, pd.MultiIndex):
#      12     close_prices = data['Close'][ticker].dropna()
#      13 else:
#
# NameError: name 'pd' is not defined

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# Choose stock ticker
ticker = 'AAPL'

# Download 30 days of data
data = yf.download(ticker, period='30d')

# Handle multi-index or unexpected structure
if isinstance(data.columns, pd.MultiIndex):
    close_prices = data['Close'][ticker].dropna()
else:
    close_prices = data['Close'].dropna()

# Check again to avoid errors
if not close_prices.empty:
    print(f"\nStock: {ticker}")
    print(f"Minimum Close Price: {float(close_prices.min()):.2f}")
    print(f"Maximum Close Price: {float(close_prices.max()):.2f}")
    print(f"Average Close Price: {float(close_prices.mean()):.2f}")

    # Plot
    plt.figure(figsize=(10, 5))
    plt.plot(close_prices.index, close_prices, label='Close Price', color='blue')
    plt.title(f'{ticker} Stock Closing Prices - Last 30 Days')
    plt.xlabel('Date')
    plt.ylabel('Price ($)')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()
else:
    print("No closing price data available.")
# Out:
# /tmp/ipython-input-7-3867230606.py:9: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, period='30d')
# [*********************100%***********************]  1 of 1 completed
# Stock: AAPL
# Minimum Close Price: 195.64
# Maximum Close Price: 213.55
# Average Close Price: 204.76
